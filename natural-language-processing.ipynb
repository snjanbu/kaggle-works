# %% [markdown]
# <a href="https://www.kaggle.com/sanjayanbu/natural-language-processing?scriptVersionId=88728592" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Importing required libraries

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import re
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec

# %% [markdown]
# ## Taking random paragraph

# %%
paragraph= """In academic writing, readers expect each paragraph to have a sentence or two that captures its main point. They’re often called “topic sentences,” though many writing instructors prefer to call them “key sentences.” There are at least two downsides of the phrase “topic sentence.” First, it makes it seem like the paramount job of that sentence is simply to announce the topic of the paragraph. Second, it makes it seem like the topic sentence must always be a single grammatical sentence. Calling it a “key sentence” reminds us that it expresses the central idea of the paragraph. And sometimes a question or a two-sentence construction functions as the key."""

# %% [markdown]
# ## Tokenization

# %%
sentences = nltk.sent_tokenize(paragraph)

# %% [markdown]
# ## Creating stem object

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ## Text preprocessing like stopwords removal and stemming

# %%
stem_sentences = sentences
lemmatize_sentences = sentences

# %%
stem_word_list = []
lemmatize_word_list = []
corpus_list = []
for i in range(len(sentences)):
#     Removing characters other than alphabets
    sentences[i] = re.sub('[^a-zA-Z]', ' ', sentences[i])
    sentences[i] = sentences[i].lower()
#     Word tokenizing the sentences
    word_token = nltk.word_tokenize(sentences[i])
#     Constructing stem word list
    stem_word_list.append(" ".join([stemmer.stem(word) for word in word_token if word not in set(stopwords.words('english'))]))
#     Constructiong lemmatize word list
    lemmatize_word_list.append(" ".join([lemmatizer.lemmatize(word) for word in word_token if word not in set(stopwords.words('english'))]))
#     Corpus List
    corpus_list.append([lemmatizer.lemmatize(word) for word in word_token if word not in set(stopwords.words("english"))])

# %%
cv = CountVectorizer()
bw = cv.fit_transform(stem_word_list)

# %%
bw.toarray().shape
# Out:
# (5, 43)

# %%
tfidfvectorizer = TfidfVectorizer()
tf_words = tfidfvectorizer.fit_transform(lemmatize_word_list)

# %%
tf_words.shape
# Out:
# (5, 44)

# %%
word2vector = Word2Vec(corpus_list, min_count=2)

# %%
word2vector.wv.key_to_index
# Out:
# {'sentence': 0,
#  'topic': 1,
#  'key': 2,
#  'two': 3,
#  'paragraph': 4,
#  'like': 5,
#  'seem': 6,
#  'make': 7,
#  'writing': 8}
